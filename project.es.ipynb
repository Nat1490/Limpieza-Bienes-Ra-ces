# %% [markdown]
# # Limpieza de bienes raíces
#
# Este es un conjunto de datos (dataset) reales que fue descargado usando técnicas de web scraping. La data contiene registros de **Fotocasa**, el cual es uno de los sitios más populares de bienes raíces en España. Por favor no hagas esto (web scraping) a no ser que sea para propósitos académicos.
#
# El dataset fue descargado hace algunos años por Henry Navarro y en ningún caso se obtuvo beneficio económico de ello.
#
# Contiene miles de datos de casas reales publicadas en la web www.fotocasa.com. Tu objetivo es extraer tanta información como sea posible con el conocimiento que tienes hasta ahora de ciencia de datos, por ejemplo ¿cuál es la casa más cara en todo el dataset?
#
# Empecemos precisamente con esa pregunta... ¡Buena suerte!

# %% [markdown]
# #### Ejercicio 00. Lee el dataset assets/real_estate.csv e intenta visualizar la tabla (★☆☆)

# %%
import pandas as pd

# Este archivo CSV contiene puntos y comas en lugar de comas como separadores
ds = pd.read_csv('assets/real_estate.csv', sep=';')
ds.head(10)
# Out:
#    Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0           1       153771986  False            ferrari 57 inmobiliaria
# 1           2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2           3       153430440  False                 look find boadilla
# 3           4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4           5       153180188  False            ferrari 57 inmobiliaria
# 5           6       153934794  False                            expimad
# 6           7       153848236  False                            expimad
# 7           8       153482331  False                            expimad
# 8           9       153885351  False                            expimad
# 9          10       153215459  False                            modesta
#
#    phone_realEstate                                       url_inmueble  rooms  \
# 0       912177526.0  https://www.fotocasa.es/es/comprar/vivienda/ma...    3.0
# 1       916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...    3.0
# 2       916350408.0  https://www.fotocasa.es/es/comprar/vivienda/ma...    2.0
# 3       916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...    3.0
# 4       912177526.0  https://www.fotocasa.es/es/comprar/vivienda/ma...    2.0
# 5       912780412.0  https://www.fotocasa.es/es/comprar/vivienda/ma...    2.0
# 6       912780412.0  https://www.fotocasa.es/es/comprar/vivienda/ma...    3.0
# 7       912780412.0  https://www.fotocasa.es/es/comprar/vivienda/ma...    2.0
# 8       912780412.0  https://www.fotocasa.es/es/comprar/vivienda/ma...    4.0
# 9               NaN  https://www.fotocasa.es/es/comprar/vivienda/ma...    4.0
#
#    bathrooms  surface   price  ... level4Id level5Id level6Id level7Id  \
# 0        2.0    103.0  195000  ...        0        0        0        0
# 1        1.0      NaN   89000  ...        0        0        0        0
# 2        2.0     99.0  390000  ...        0        0        0        0
# 3        1.0     86.0   89000  ...        0        0        0        0
# 4        2.0    106.0  172000  ...        0        0        0        0
# 5        1.0     70.0  315000  ...        0        0        0        0
# 6        2.0    145.0  430000  ...        0        0        0        0
# 7        1.0     95.0  275000  ...        0        0        0        0
# 8        3.0    277.0  445000  ...        0        0        0        0
# 9        2.0    129.0  350000  ...        0        0        0        0
#
#   level8Id accuracy          latitude          longitude zipCode customZone
# 0        0        0  40,2948276786438  -3,44402412135624     NaN        NaN
# 1        0        1          40,28674           -3,79351     NaN        NaN
# 2        0        0  40,4115646786438  -3,90662252135624     NaN        NaN
# 3        0        0  40,2853785786438  -3,79508142135624     NaN        NaN
# 4        0        0  40,2998774864376  -3,45226301356237     NaN        NaN
# 5        0        0          40,53391           -3,89445     NaN        NaN
# 6        0        0  40,5105842135624  -3,89436578643763     NaN        NaN
# 7        0        0          40,53294           -3,89898     NaN        NaN
# 8        0        0  40,5363057864376  -3,89294421356237     NaN        NaN
# 9        0        0          40,37502           -3,74391     NaN        NaN
#
# [10 rows x 37 columns]

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15335 entries, 0 to 15334
# Data columns (total 37 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        15335 non-null  int64
#  1   id_realEstates    15335 non-null  int64
#  2   isNew             15335 non-null  bool
#  3   realEstate_name   15325 non-null  object
#  4   phone_realEstate  14541 non-null  float64
#  5   url_inmueble      15335 non-null  object
#  6   rooms             14982 non-null  float64
#  7   bathrooms         14990 non-null  float64
#  8   surface           14085 non-null  float64
#  9   price             15335 non-null  int64
#  10  date              15335 non-null  object
#  11  description       15193 non-null  object
#  12  address           15335 non-null  object
#  13  country           15335 non-null  object
#  14  level1            15335 non-null  object
#  15  level2            15335 non-null  object
#  16  level3            15335 non-null  object
#  17  level4            8692 non-null   object
#  18  level5            15335 non-null  object
#  19  level6            708 non-null    object
#  20  level7            13058 non-null  object
#  21  level8            6756 non-null   object
#  22  upperLevel        15335 non-null  object
#  23  countryId         15335 non-null  int64
#  24  level1Id          15335 non-null  int64
#  25  level2Id          15335 non-null  int64
#  26  level3Id          15335 non-null  int64
#  27  level4Id          15335 non-null  int64
#  28  level5Id          15335 non-null  int64
#  29  level6Id          15335 non-null  int64
#  30  level7Id          15335 non-null  int64
#  31  level8Id          15335 non-null  int64
#  32  accuracy          15335 non-null  int64
#  33  latitude          15335 non-null  object
#  34  longitude         15335 non-null  object
#  35  zipCode           0 non-null      float64
#  36  customZone        0 non-null      float64
# dtypes: bool(1), float64(6), int64(13), object(17)
# memory usage: 4.2+ MB

# %% [markdown]
# #### Ejercicio 01. ¿Cuál es la casa más cara en todo el dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle del Prado, Nº20 es la más cara y su precio es de 5000000 USD`

# %%
# TODO
precio_max=ds.loc[ds["price"].idxmax()]

print(f"La casa con dirección en {precio_max["url_inmueble"]} es la más cara y su precio es de {precio_max} USD")
# Out:
# La casa con dirección en https://www.fotocasa.es/es/comprar/vivienda/villaviciosa-de-odon/aire-acondicionado-calefaccion-parking-jardin-terraza-trastero-piscina-internet/144725475/d es la más cara y su precio es de Unnamed: 0                                                      13111
# id_realEstates                                              132042636
# isNew                                                           False
# realEstate_name                            engel volkers torrelodones
# phone_realEstate                                          911798512.0
# url_inmueble        https://www.fotocasa.es/es/comprar/vivienda/vi...
# rooms                                                            19.0
# bathrooms                                                         NaN
# surface                                                           NaN
# price                                                         8500000
# date                                             2019-12-19T12:29:00Z
# description         El Palacio de El Enebral, la finca fue propied...
# address                                                   El Escorial
# country                                                        España
# level1                                                         Madrid
# level2                                                         Madrid
# level3                                                  Zona Noroeste
# level4                                           El Escorial, Zona de
# level5                                                    El Escorial
# level6                                                            NaN
# level7                                             Centro - Manquilla
# level8                                                            NaN
# upperLevel                                         Centro - Manquilla
# countryId                                                           0
# level1Id                                                            0
# level2Id                                                            0
# level3Id                                                            0
# level4Id                                                            0
# level5Id                                                            0
# level6Id                                                            0
# level7Id                                                            0
# level8Id                                                            0
# accuracy                                                            0
# latitude                                             40,5830801751782
# longitude                                           -4,12951942848611
# zipCode                                                           NaN
# customZone                                                        NaN
# Name: 13110, dtype: object USD

# %% [markdown]
# #### Ejercicio 02. ¿Cuál es la casa más barata del dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle Alcalá, Nº58 es la más barata y su precio es de 12000 USD`

# %%
precio_min=ds.loc[ds["price"].idxmin()]

print(f"La casa con dirección en {precio_min["url_inmueble"]} es la más barata y su precio es de {precio_min} USD")
# Out:
# La casa con dirección en https://www.fotocasa.es/es/comprar/vivienda/madrid-capital/aire-acondicionado-calefaccion-terraza-ascensor/153310413/d es la más barata y su precio es de Unnamed: 0                                                        367
# id_realEstates                                              153637952
# isNew                                                           False
# realEstate_name                                                esalje
# phone_realEstate                                          912786497.0
# url_inmueble        https://www.fotocasa.es/es/comprar/vivienda/ma...
# rooms                                                             4.0
# bathrooms                                                         4.0
# surface                                                         262.0
# price                                                               0
# date                                      2019-12-28T18:52:25.965658Z
# description         ESALJE vende amplio pareado de 268 m2. distrib...
# address                                                         Parla
# country                                                        España
# level1                                                         Madrid
# level2                                                         Madrid
# level3                                             Zona Sur de Madrid
# level4                                                 Parla, Zona de
# level5                                                          Parla
# level6                                                            NaN
# level7                                          Fuentebella - El Nido
# level8                                                            NaN
# upperLevel                                      Fuentebella - El Nido
# countryId                                                           0
# level1Id                                                            0
# level2Id                                                            0
# level3Id                                                            0
# level4Id                                                            0
# level5Id                                                            0
# level6Id                                                            0
# level7Id                                                            0
# level8Id                                                            0
# accuracy                                                            0
# latitude                                                     40,23202
# longitude                                                    -3,78132
# zipCode                                                           NaN
# customZone                                                        NaN
# Name: 366, dtype: object USD

# %% [markdown]
# #### Ejercicio 03. ¿Cuál es la casa más grande y la más pequeña del dataset? (★☆☆)
#
# Imprime la dirección y el área de las casas seleccionadas. Por ejemplo:
#
# `La casa más grande está ubicada en Calle Gran Vía, Nº38 y su superficie es de 5000 metros`
#
# `La casa más pequeña está ubicada en Calle Mayor, Nº12 y su superficie es de 200 metros`

# %%
surface_max=ds.loc[ds["surface"].idxmax()]

print(f"La casa con dirección en {surface_max["url_inmueble"]} es la más grande es de {surface_max} m2")
# Out:
# La casa con dirección en https://www.fotocasa.es/es/comprar/vivienda/madrid-capital/calefaccion-terraza-ascensor/153268668/d es la más grande es de Unnamed: 0                                                       6795
# id_realEstates                                              153936192
# isNew                                                           False
# realEstate_name                               habitarium inmobiliaria
# phone_realEstate                                          916357732.0
# url_inmueble        https://www.fotocasa.es/es/comprar/vivienda/ma...
# rooms                                                             3.0
# bathrooms                                                         2.0
# surface                                                      249000.0
# price                                                          289000
# date                                             2019-12-25T18:30:00Z
# description         Zona Centro. Chalet pareado de esquina de 249m...
# address                                              Sevilla la Nueva
# country                                                        España
# level1                                                         Madrid
# level2                                                         Madrid
# level3                                                  Zona Suroeste
# level4                                      Sevilla la Nueva, Zona de
# level5                                               Sevilla la Nueva
# level6                                                            NaN
# level7                                                            NaN
# level8                                                            NaN
# upperLevel                                           Sevilla la Nueva
# countryId                                                           0
# level1Id                                                            0
# level2Id                                                            0
# level3Id                                                            0
# level4Id                                                            0
# level5Id                                                            0
# level6Id                                                            0
# level7Id                                                            0
# level8Id                                                            0
# accuracy                                                            0
# latitude                                                     40,34633
# longitude                                                    -4,02174
# zipCode                                                           NaN
# customZone                                                        NaN
# Name: 6794, dtype: object m2

# %%
surface_min=ds.loc[ds["surface"].idxmin()]

print(f"La casa con dirección en {surface_min["url_inmueble"]} es la más grande es de {surface_min} m2")
# Out:
# La casa con dirección en https://www.fotocasa.es/es/comprar/vivienda/madrid-capital/aire-acondicionado-calefaccion-trastero/153764741/d es la más grande es de Unnamed: 0                                                        499
# id_realEstates                                              152817874
# isNew                                                           False
# realEstate_name                                              toledo21
# phone_realEstate                                          910757382.0
# url_inmueble        https://www.fotocasa.es/es/comprar/vivienda/ma...
# rooms                                                             1.0
# bathrooms                                                         1.0
# surface                                                          15.0
# price                                                           85000
# date                                     2019-12-28T19:04:44.6433814Z
# description         ¡NO BUSQUES MÁS, YA LA HAS ENCONTRADO! . \n \n...
# address                                 Calle Amparo,  Madrid Capital
# country                                                        España
# level1                                                         Madrid
# level2                                                         Madrid
# level3                                                Madrid, Zona de
# level4                                                            NaN
# level5                                                 Madrid Capital
# level6                                                            NaN
# level7                                                         Centro
# level8                                         Embajadores - Lavapiés
# upperLevel                                     Embajadores - Lavapiés
# countryId                                                           0
# level1Id                                                            0
# level2Id                                                            0
# level3Id                                                            0
# level4Id                                                            0
# level5Id                                                            0
# level6Id                                                            0
# level7Id                                                            0
# level8Id                                                            0
# accuracy                                                            0
# latitude                                                     40,40818
# longitude                                                    -3,70192
# zipCode                                                           NaN
# customZone                                                        NaN
# Name: 498, dtype: object m2

# %% [markdown]
# #### Ejercicio 04. ¿Cuantas poblaciones (columna level5) contiene el dataset? (★☆☆)
#
# Imprime el nombre de las poblaciones separadas por coma. Por ejemplo:
#
# `> print(populations)`
#
# `population1, population2, population3, ...`

# %%
populations_list = ds['level5'].tolist() 
populations_set = set(populations_list)
populations_list = list(populations_set)
print(f"Hay unas {len(populations_list)} diferentes las cuales son: {populations_list}")
# Out:
# Hay unas 168 diferentes las cuales son: ['Torremocha de Jarama', 'Colmenar Viejo', 'Lozoyuela-navas-sieteiglesias', 'Guadalix de la Sierra', 'Batres', 'Hoyo de Manzanares', 'Alcorcón', 'Valdemaqueda', 'Gascones', 'Majadahonda', 'El Boalo - Cerceda – Mataelpino', 'Nuevo Baztán', 'Valdelaguna', 'Villanueva de Perales', 'Cercedilla', 'Fresno de Torote - Serracines', 'Aranjuez', 'Ajalvir', 'El Molar (Madrid)', 'Loeches', 'Fuentidueña de Tajo', 'Robregordo', 'Navalafuente', 'Venturada', 'La Hiruela', 'Villaviciosa de Odón', 'Alpedrete', 'Valdemorillo', 'Torrelodones', 'Estremera', ' Madrid Capital', 'Horcajo de la Sierra', 'Torrejón de la Calzada', 'Moraleja de Enmedio', 'Villaconejos', 'Parla', 'Griñón', 'Cobeña', 'San Agustín del Guadalix', 'El Vellón', 'Cenicientos', 'El Escorial', 'San Fernando de Henares', 'Valdemanco', 'San Martín de la Vega', 'Anchuelo', 'Algete', 'Cadalso de los Vidrios', 'Pozuelo del Rey', 'Buitrago del Lozoya', 'Humanes de Madrid', 'Tres Cantos', 'Valdemoro', 'Los Molinos', 'Las Rozas de Madrid', 'Villanueva del Pardillo', 'Garganta de los Montes', 'San Sebastián de los Reyes', 'Valverde de Alcalá', 'Chapinería', 'Collado Mediano', 'Villa del Prado', 'Villamantilla', 'Boadilla del Monte', 'Belmonte de Tajo', 'Ribatejada', 'Villamanrique de Tajo', 'San Martín de Valdeiglesias', 'Pelayos de la Presa', 'Villamanta', 'Piñuécar-gandullas', 'Fuente El Saz de Jarama', 'Velilla de San Antonio', 'Rivas-vaciamadrid', 'Valdetorres de Jarama', 'Alcalá de Henares', 'Pedrezuela', 'Redueña', 'Robledo de Chavela', 'Torrejón de Ardoz', 'Valdepiélagos', 'Pozuelo de Alarcón', 'Alcobendas', 'Tielmes', 'Torrejón de Velasco', 'Los Santos de la Humosa', 'El Álamo', 'El Berrueco', 'Camarma de Esteruelas', 'Santa María de la Alameda', 'Daganzo de Arriba', 'Titulcia', 'Lozoya', 'Miraflores de la Sierra', 'Quijorna', 'Corpa', 'Colmenarejo', 'Moralzarzal', 'Arganda del Rey', 'Ambite', 'Bustarviejo', 'Perales de Tajuña', 'Manzanares El Real', 'Patones', 'Fresno de Torote', 'Villar del Olmo', 'Navarredonda', 'Brea de Tajo', 'Zarzalejo', 'Brunete', 'Villavieja del Lozoya', 'Villarejo de Salvanés', 'Valdilecha', 'Rascafría', 'Paracuellos de Jarama', 'Colmenar de Oreja', 'Navas del Rey', 'Cubas de la Sagra', 'Sevilla la Nueva', 'Collado Villalba', 'Morata de Tajuña', 'Galapagar', 'Orusco de Tajuña', 'Serranillos del Valle', 'Gargantilla del Lozoya', 'Soto del Real', 'Pezuela de las Torres', 'Colmenar del Arroyo', 'San Lorenzo de El Escorial', 'Puentes Viejas', 'Coslada', 'Pinilla del Valle', 'Madarcos', 'Chinchón', 'El Atazar', 'Casarrubuelos', 'Campo Real', 'Leganés', 'Torres de la Alameda', 'Montejo de la Sierra', 'Villalbilla', 'Valdaracete', 'La Cabrera', 'Fuenlabrada', 'Becerril de la Sierra', 'Carabaña', 'Braojos', 'Navalcarnero', 'Canencia', 'Meco', 'Villanueva de la Cañada', 'Valdeavero', 'Fresnedillas de la Oliva', 'Navalagamella', 'Valdeolmos-Alalpardo', 'Navacerrada', 'Móstoles', 'Ciempozuelos', 'Mejorada del Campo', 'Cabanillas de la Sierra', 'Pinto', 'Guadarrama', 'Talamanca de Jarama', 'Torrelaguna', 'Arroyomolinos (Madrid)', 'Aldea del Fresno', 'Santorcaz', 'Getafe']

# %% [markdown]
# #### Ejercicio 05. ¿El dataset contiene valores no admitidos (NAs)? (★☆☆)
#
# Imprima un booleano (`True` o `False`) seguido de la fila/columna que contiene el NAs.

# %%
has_nules=ds.isna().any()
print(has_nules)

print(has_nules[has_nules].index.tolist())
# Out:
# Unnamed: 0          False
# id_realEstates      False
# isNew               False
# realEstate_name      True
# phone_realEstate     True
# url_inmueble        False
# rooms                True
# bathrooms            True
# surface              True
# price               False
# date                False
# description          True
# address             False
# country             False
# level1              False
# level2              False
# level3              False
# level4               True
# level5              False
# level6               True
# level7               True
# level8               True
# upperLevel          False
# countryId           False
# level1Id            False
# level2Id            False
# level3Id            False
# level4Id            False
# level5Id            False
# level6Id            False
# level7Id            False
# level8Id            False
# accuracy            False
# latitude            False
# longitude           False
# zipCode              True
# customZone           True
# dtype: bool
# ['realEstate_name', 'phone_realEstate', 'rooms', 'bathrooms', 'surface', 'description', 'level4', 'level6', 'level7', 'level8', 'zipCode', 'customZone']

# %%
total_nans = ds.isna().sum()
total_nans
# Out:
# Unnamed: 0              0
# id_realEstates          0
# isNew                   0
# realEstate_name        10
# phone_realEstate      794
# url_inmueble            0
# rooms                 353
# bathrooms             345
# surface              1250
# price                   0
# date                    0
# description           142
# address                 0
# country                 0
# level1                  0
# level2                  0
# level3                  0
# level4               6643
# level5                  0
# level6              14627
# level7               2277
# level8               8579
# upperLevel              0
# countryId               0
# level1Id                0
# level2Id                0
# level3Id                0
# level4Id                0
# level5Id                0
# level6Id                0
# level7Id                0
# level8Id                0
# accuracy                0
# latitude                0
# longitude               0
# zipCode             15335
# customZone          15335
# dtype: int64

# %% [markdown]
# #### Ejercicio 06. Elimina los NAs del dataset, si aplica (★★☆)
#
# Imprima una comparación entre las dimensiones del DataFrame original versus el DataFrame después de las eliminaciones.

# %%
na_full_columns = []

# Find columns with only NaN values
for column in ds.columns:
    if ds[column].isna().all():
        na_full_columns.append(column)

# Remove columns with only NaN values
ds_drop = ds.drop(na_full_columns, axis=1)

# Fill NaN with 0's
ds_filled = ds_drop.fillna(0)

full_0_columns = []

# Find all columns with only 0's on them
for column in ds_filled.columns:
    if all(value == 0 for value in ds_filled[column]):
        full_0_columns.append(column)

# Remove columns with only 0's 
ds_clean = ds_filled.drop(full_0_columns, axis=1)

# Convert longitude and latitude columns from str to float, first replacing all ',' with '.'
ds_clean['latitude'] = ds_clean['latitude'].str.replace(',','.')
ds_clean['longitude'] = ds_clean['longitude'].str.replace(',','.')

ds_clean['latitude'] = ds_clean['latitude'].astype(float)
ds_clean['longitude'] = ds_clean['longitude'].astype(float)

# Remove all rows with price, surface == 0 and with latitude & longitude if both are == 0
ds_clean = ds_clean[(ds_clean['price'] != 0) & (ds_clean['surface'] != 0) & ~((ds_clean['latitude'] == 0) & (ds_clean['longitude'] == 0))]


print("Before removing NA columns: ", ds.shape)
print("After: ", ds_clean.shape)
# Out:
# Before removing NA columns:  (15335, 37)
# After:  (14016, 26)

# %% [markdown]
# #### Ejercicio 07. ¿Cuál la media de precios en la población (columna level5) de "Arroyomolinos (Madrid)"? (★★☆)
#
# Imprima el valor obtenido.

# %%
import statistics as stats

ds_arroyomolinos = ds_clean[ds_clean['level5'] == 'Arroyomolinos (Madrid)']
 
print(f"El precio medio en Arroyomolinos (Madrid) es", round(ds_arroyomolinos['price'].mean(),2))
# Out:
# El precio medio en Arroyomolinos (Madrid) es 299892.69

# %% [markdown]
# #### Ejercicio 08. Trazar el histograma de los precios para la población (level5 column) de "Arroyomolinos (Madrid)" y explica qué observas (★★☆)
#
# Imprime el histograma de los precios y escribe en la celda del Markdown un breve análisis del trazado.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (10, 5))

plt.hist(ds_arroyomolinos['price'], bins = 40, alpha = 0.7)

plt.title("Histogram")
plt.xlabel("Price")
plt.ylabel("Amount")
plt.show()

# %% [markdown]
# Observamos que gran parte de los inmuebles estan dentro de los 200€-400€ de rango, especifíciamente alrededor de los 290€.
# Existen unos cuantos outliers alrededor de los 600€ y unos pocos que no muestran precio.

# %% [markdown]
# #### Ejercicio 09. ¿Son los precios promedios de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios y escribe una conclusión sobre ellos.

# %%
ds_valdemorillo = ds_clean[ds_clean['level5'] == 'Valdemorillo']
ds_galapagar = ds_clean[ds_clean['level5'] == 'Galapagar']

print(f"Precio promedio Valdemorillo: {round(ds_valdemorillo['price'].mean(),2)}")
print(f"Precio promedio: {round(ds_galapagar['price'].mean(),2)}")
# Out:
# Precio promedio Valdemorillo: 371583.02
# Precio promedio: 372108.65

# %% [markdown]
# Como podemos observar, no tienen los mismo precio medio.

# %% [markdown]
# #### Ejercicio 10. ¿Son los promedios de precio por metro cuadrado (precio/m2) de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios de precio por metro cuadrado y escribe una conclusión sobre ellos.
#
# Pista: Crea una nueva columna llamada `pps` (*price per square* o precio por metro cuadrado) y luego analiza los valores.

# %%
import numpy as np

# Create new column pps = price/surface with exception to replace 0's with NaN to avoid inf outputs
ds_valdemorillo['pps'] = ds_valdemorillo['price'] / ds_valdemorillo['surface']
ds_galapagar['pps'] = ds_galapagar['price'] / ds_galapagar['surface']
# Out:
# /var/folders/6c/p_0npg6n1z9_zwvz0g0jksl40000gn/T/ipykernel_85474/1112423543.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ds_valdemorillo['pps'] = ds_valdemorillo['price'] / ds_valdemorillo['surface']
# /var/folders/6c/p_0npg6n1z9_zwvz0g0jksl40000gn/T/ipykernel_85474/1112423543.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ds_galapagar['pps'] = ds_galapagar['price'] / ds_galapagar['surface']

# %%
print(f"Valdemorillo pps promedio: {round(ds_valdemorillo['pps'].mean(),2)} with {len(ds_valdemorillo['price'])} different houses")
print(f"Galapagar pps promedio: {round(ds_galapagar['pps'].mean(),2)} with {len(ds_galapagar['price'])} different houses")
# Out:
# Valdemorillo pps promedio: 1317.95 with 53 different houses
# Galapagar pps promedio: 1606.32 with 75 different houses

# %% [markdown]
# #### Ejercicio 11. Analiza la relación entre la superficie y el precio de las casas. (★★☆)
#
# Pista: Puedes hacer un `scatter plot` y luego escribir una conclusión al respecto.

# %%
# Create plot
plt.figure(figsize = (10, 5))

# Add data
plt.scatter(ds_valdemorillo['price'], ds_valdemorillo['surface'], label = "Valdemorillo")
plt.scatter(ds_galapagar['price'], ds_galapagar['surface'], label = "Galapagar")

plt.title("Scatter plot")
plt.xlabel("Price")
plt.ylabel("Surface (m2)")
plt.legend()
plt.show()

# %% [markdown]
# Como podemos observar, el previo medio de las casas en Galapagar es más alto en comparación con los inmuebles situados en Valdemorillo pero, estos son de media un poco más grandes.

# %% [markdown]
# #### Ejercicio 12. ¿Cuántas agencia de bienes raíces contiene el dataset? (★★☆)
#
# Imprime el valor obtenido.

# %%
print(f"Hay {len(ds_clean['realEstate_name'].unique())} inmobiliarias")
# Out:
# Hay 1704 inmobiliarias

# %% [markdown]
# #### Ejercicio 13. ¿Cuál es la población (columna level5) que contiene la mayor cantidad de casas?(★★☆)
#
# Imprima la población y el número de casas.

# %%
duplicates = ds_clean['level5'].value_counts()

most_common = duplicates.idxmax()
most_common_count = duplicates.max()

print(f"The most common population is {most_common} with {most_common_count} houses")
# Out:
# The most common population is  Madrid Capital with 6228 houses

# %% [markdown]
# #### Ejercicio 14. Ahora vamos a trabajar con el "cinturón sur" de Madrid. Haz un subconjunto del DataFrame original que contenga las siguientes poblaciones (columna level5): "Fuenlabrada", "Leganés", "Getafe", "Alcorcón" (★★☆)
#
# Pista: Filtra el DataFrame original usando la columna `level5` y la función `isin`.

# %%
ds_southbelt = ds_clean[ds_clean['level5'].isin(['Fuenlabrada', 'Leganés', 'Getafe', 'Alcorcón'])]

# %% [markdown]
# #### Ejercicio 15. Traza un gráfico de barras de la mediana de los precios y explica lo que observas (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprima un gráfico de barras de la mediana de precios y escriba en la celda Markdown un breve análisis sobre el gráfico.

# %%
pop = ['Fuenlabrada', 'Leganés', 'Getafe', 'Alcorcón']

def get_mean_southbelt(col):
    values = []
    
    for n in pop:
        ds_aux = ds_southbelt[ds_southbelt['level5'] == n]
        values.append(round(ds_aux[col].mean(), 3))
    return values

plt.figure(figsize = (10, 5))

plt.bar(pop, get_mean_southbelt('price'))

plt.title("South Belt of Madrid")
plt.xlabel("Population")
plt.ylabel("Mean Price")
plt.show()

# %% [markdown]
# Podemos observar que, en orden descendiente, el precio promedio de una casa se encuentra en las siguientes poblaciones del Cinturón Sur de Madrid: Getafe, Alcorcón, Leganés y Fuenlabrada.

# %% [markdown]
# #### Ejercicio 16. Calcula la media y la varianza de muestra para las siguientes variables: precio, habitaciones, superficie y baños (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprime ambos valores por cada variable.

# %%
def get_variance_southbelt(df : pd.DataFrame, column_check : pd.Series, mean_value : float):
    # variance = (Sum((data_list - mean_value) ** 2))/n_elements
    variance = ((df[column_check] - mean_value) ** 2).sum() / len(df)
    return round(variance, 3)


cols_to_get = ['price', 'rooms', 'surface', 'bathrooms'] # columnas donde queremos saber la media y/o varianza


aux = 0 # Para saber en qué columna estamos
for col in cols_to_get:
    mean_v = get_mean_southbelt(col) # conseguimos la media y la guardamos
    variance_v = get_variance_southbelt(ds, col, mean_v[aux]) # conseguimos la varianza, miramos la media en mean_v[aux] donde aux es la posición del vector que coincide con cols_to_get siempre
    print(f"The mean {col} is {mean_v[aux]} and the variance is {variance_v}") # imprimimos por pantalla
    aux+=1 # We move to next cols_to_get index
# Out:
# The mean price is 180955.426 and the variance is 437428289601.343
# The mean rooms is 2.892 and the variance is 2.009
# The mean surface is 121.146 and the variance is 4381033.622
# The mean bathrooms is 1.622 and the variance is 1.905

# %% [markdown]
# #### Ejercicio 17. ¿Cuál es la casa más cara de cada población? Debes usar el subset obtenido en la pregunta 14 (★★☆)
#
# Imprime tanto la dirección como el precio de la casa seleccionada de cada población. Puedes imprimir un DataFrame o una sola línea para cada población.

# %%
# pop = ['Fuenlabrada', 'Leganés', 'Getafe', 'Alcorcón']

def get_max(df, col): # Averiguar el valor mas alto de la columna del df
    index_values = []
    
    for n in pop:
        df_aux = df[df['level5'] == n]
        index_values.append(df_aux[col].idxmax())
    return index_values # lista con indices de las casas con los valores maximos respectivamente de cada pop

max_price_index = get_max(ds_southbelt, 'price') # Cogemos los indices donde el precio es máximo respecto a cada población

print(max_price_index)
ds_southbelt.loc[max_price_index] # muestra las filas y necesita como argumento los indices
# Out:
# [11561, 10412, 2881, 5585]
#        Unnamed: 0  id_realEstates  isNew  \
# 11561       11562       153660921  False
# 10412       10413       152251506  False
# 2881         2882       151105544  False
# 5585         5586       153275915  False
#
#                                realEstate_name  phone_realEstate  \
# 11561                              unna madrid       912780846.0
# 10412  bafre gestion y servicios inmobiliarios       910752245.0
# 2881                   unna grupo inmobiliario       912665694.0
# 5585                 100 home red inmobiliaria       912669623.0
#
#                                             url_inmueble  rooms  bathrooms  \
# 11561  https://www.fotocasa.es/es/comprar/vivienda/va...    4.0        3.0
# 10412  https://www.fotocasa.es/es/comprar/vivienda/co...    6.0        5.0
# 2881   https://www.fotocasa.es/es/comprar/vivienda/ma...    6.0        4.0
# 5585   https://www.fotocasa.es/es/comprar/vivienda/ca...    6.0        6.0
#
#        surface    price  ...              level3                level4  \
# 11561    274.0   490000  ...  Zona Sur de Madrid  Fuenlabrada, Zona de
# 10412    360.0   650000  ...  Zona Sur de Madrid      Leganés, Zona de
# 2881     600.0  1050000  ...  Zona Sur de Madrid       Getafe, Zona de
# 5585     722.0   950000  ...       Zona Suroeste     Alcorcón, Zona de
#
#             level5 level6                                 level7 level8  \
# 11561  Fuenlabrada      0  Universidad - Hospital en Fuenlabrada      0
# 10412      Leganés      0                          Leganés Norte      0
# 2881        Getafe      0                             San Isidro      0
# 5585      Alcorcón      0           Campodón - Ventorro del Cano      0
#
#                                   upperLevel accuracy   latitude longitude
# 11561  Universidad - Hospital en Fuenlabrada        1  40.282860 -3.814750
# 10412                          Leganés Norte        0  40.342364 -3.748144
# 2881                              San Isidro        0  40.302820 -3.728170
# 5585            Campodón - Ventorro del Cano        0  40.353517 -3.866468
#
# [4 rows x 26 columns]

# %% [markdown]
# #### Ejercicio 18. Normaliza la variable de precios para cada población y traza los 4 histogramas en el mismo gráfico (debes usar el subconjunto obtenido en la pregunta 14) (★★★)
#
# Para el método de normalización, puedes usar el que consideres adecuado, no hay una única respuesta correcta para esta pregunta. Imprime el gráfico y escribe en la celda de Markdown un breve análisis sobre el gráfico.
#
# Pista: Puedes ayudarte revisando la demostración multihist de Matplotlib.

# %%
def normalize(df):
    return (df - df.min()) / (df.max() - df.min())

ds_southbelt['normalized_prices'] = ds_southbelt.groupby('level5')['price'].transform(normalize)

populations = ds_southbelt['level5'].unique()
num_populations = len(populations)

# Create generic plot
plt.figure(figsize=(10, 5))

# Add subsets of data to the plot
for population in populations:
    subset = ds_southbelt[ds_southbelt['level5'] == population]
    plt.hist(subset['normalized_prices'], bins=40, alpha=1, label=f'{population}')

plt.legend()
plt.xlabel('Normalized Prices')
plt.ylabel('Frequency')
plt.title('Normalized Prices for Each Population')
plt.show()

# Create new plot and subplots
fig, axs = plt.subplots(num_populations, 1, figsize=(10, 4 * num_populations), sharex=True, sharey=True)

# Plot in subplots
for i, population in enumerate(populations):
    subset = ds_southbelt[ds_southbelt['level5'] == population]
    axs[i].hist(subset['normalized_prices'], bins=30, alpha=0.75, color=np.random.rand(3,))
    axs[i].set_title(f'{population}')
    axs[i].set_xlabel('Normalized Prices')
    axs[i].set_ylabel('Frequency')
# Out:
# /var/folders/6c/p_0npg6n1z9_zwvz0g0jksl40000gn/T/ipykernel_85474/4249044423.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ds_southbelt['normalized_prices'] = ds_southbelt.groupby('level5')['price'].transform(normalize)

# %% [markdown]
# Como podemos observar. el mayor outlier se encuentra en Getafe y Leganés. Getafe es considerado outlier ya que se encuentran dos rangos de precios bastante notables en diferencia con Leganés, que no son tan notables.

# %% [markdown]
# #### Ejercicio 19. ¿Qué puedes decir sobre el precio por metro cuadrado (precio/m2) entre los municipios de 'Getafe' y 'Alcorcón'? Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
#
# Pista: Crea una nueva columna llamada `pps` (price per square en inglés) y luego analiza los valores

# %%
ds_southbelt['pps'] = ds_southbelt['price'] / ds_southbelt['surface']
column_check = 'level5'
population_check_get = "Getafe"
population_check_alc = "Alcorcón"
ds_getafe = ds_southbelt[ds_southbelt[column_check] == population_check_get]
ds_alcorcon = ds_southbelt[ds_southbelt[column_check] == population_check_alc]

# Create plot  
plt.figure(figsize = (10, 5))

# Plot data
plt.scatter(ds_getafe['price'], ds_getafe['surface'], label = "Getafe")
plt.scatter(ds_alcorcon['price'], ds_alcorcon['surface'], label = "Alcorcón")

plt.title("Scatter plot")
plt.xlabel("Price")
plt.ylabel("Surface (m2)")
plt.legend()
plt.show()

print(f"Getafe pps average: {round(ds_getafe['pps'].mean(),2)} with {len(ds_getafe['price'])} different houses")
print(f"Alcorcón pps average: {round(ds_alcorcon['pps'].mean(), 2)} with {len(ds_alcorcon['price'])} different houses")
# Out:
# /var/folders/6c/p_0npg6n1z9_zwvz0g0jksl40000gn/T/ipykernel_85474/1456487739.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ds_southbelt['pps'] = ds_southbelt['price'] / ds_southbelt['surface']
# Getafe pps average: 2206.29 with 219 different houses
# Alcorcón pps average: 2248.81 with 172 different houses

# %% [markdown]
# Getafe y Alcorcón tienen unos cuantos outliers que aparecen en venta por partida doble. El resto podemos observar que son bastante parejos y es lógico, ya que tienen un promedio pps bastante equiparable.

# %% [markdown]
# #### Ejercicio 20. Realiza el mismo gráfico para 4 poblaciones diferentes (columna level5) y colócalos en el mismo gráfico. Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
# Pista: Haz un diagrama de dispersión de cada población usando subgráficos (subplots).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Get populations
populations = ds_southbelt['level5'].unique()
num_populations = len(populations)

# Generate subplot
fig, axes = plt.subplots(num_populations, 1, figsize=(6, 3 * num_populations), sharex=True, sharey=True)


# Generate a plot for each population
for i, population in enumerate(populations):
    subset = ds_southbelt[ds_southbelt['level5'] == population]
    ax = axes[i] if num_populations > 1 else axes
    ax.scatter(subset['price'], subset['surface'], alpha = 0.7, label = population, color=np.random.rand(3,))
    ax.set_title(f'{population}')
    ax.set_xlabel('Price')
    ax.set_ylabel('Surface(m2)')

plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### Ejercicio 21. Realiza un trazado de las coordenadas (columnas latitud y longitud) del cinturón sur de Madrid por color de cada población (debes usar el subconjunto obtenido del Ejercicio 14) (★★★★)
#
# Ejecuta la siguiente celda y luego comienza a codear en la siguiente. Debes implementar un código simple que transforme las columnas de coordenadas en un diccionario de Python (agrega más información si es necesario) y agrégala al mapa.

# %%
# Exportamos latitud y longitud al diccionario
coords = ds_southbelt[['latitude', 'longitude', 'level5']].to_dict(orient='list')
latitude = 0
longitude = 0
count = len(coords['latitude'])

# Add values
for key, value in coords.items():
    for i in range(len(value)):
        if key == 'latitude':
           latitude += value[i]
        if key == 'longitude':
           longitude += value[i]

# Get average    
mean_longitude = longitude / count
mean_latitude = latitude / count

print(f"Mean Latitude: {mean_latitude}")
print(f"Mean Longitude: {mean_longitude}")
# Out:
# Mean Latitude: 40.317853508786996
# Mean Longitude: -3.7798805875538255

# %%
from ipyleaflet import Map, basemaps, Circle

# Map center at 40.31 et -3.78, correct zoom = 12
# Latitude, longitude
map = Map(center = (40.31, -3.78), zoom = 12, min_zoom = 1, max_zoom = 20, 
    basemap=basemaps.Esri.WorldTopoMap)

# %%
# Crear un diccionario que asigna colores a cada ubicación
location_color = {
    'Fuenlabrada': 'coral',
    'Alcorcón': 'purple',
    'Getafe': 'skyblue',
    'Leganés': 'yellow'
}
# Para ubicaciones no presentes en el diccionario, asignar un color por defecto (por ejemplo, 'gray')
ds_southbelt['color'] = ds_southbelt['level5'].map(location_color).fillna('gray')

# Filtrar filas con valores NaN en 'latitude' o 'longitude'
ds_southbelt = ds_southbelt.dropna(subset=['latitude', 'longitude'])

# Crear un mapa centrado en una ubicación específica (ajusta según sea necesario)
m = Map(center=(40.4168, -3.7038), zoom=10)

# Crear y agregar círculos al mapa
for idx, row in ds_southbelt.iterrows():
    if pd.notna(row['color']):
        circle = Circle(location=(row['latitude'], row['longitude']), radius=5, color=row['color'], fill_color=row['color'])
        m.add_layer(circle)

# Mostrar el mapa
m
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[35], line 29
#      27     if pd.notna(row['color']):
#      28         circle = Circle(location=(row['latitude'], row['longitude']), radius=5, color=row['color'], fill_color=row['color'])
# ---> 29         m.add_layer(circle)
#      31 # Mostrar el mapa
#      32 m
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/ipyleaflet/leaflet.py:2988, in Map.add_layer(self, layer)
#    2977 """Add a layer on the map.
#    2978
#    2979 .. deprecated :: 0.17.0
#    (...)
#    2985     The new layer to add.
#    2986 """
#    2987 warnings.warn("add_layer is deprecated, use add instead", DeprecationWarning)
# -> 2988 self.add(layer)
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/ipyleaflet/leaflet.py:3150, in Map.add(self, item, index)
#    3146         self.layers = tuple(
#    3147             list(self.layers)[:index] + [item] + list(self.layers)[index:]
#    3148         )
#    3149     else:
# -> 3150         self.layers = tuple([layer for layer in self.layers] + [item])
#    3152 elif isinstance(item, Control):
#    3153     if item.model_id in self._control_ids:
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/traitlets/traitlets.py:716, in TraitType.__set__(self, obj, value)
#     714 if self.read_only:
#     715     raise TraitError('The "%s" trait is read-only.' % self.name)
# --> 716 self.set(obj, value)
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/traitlets/traitlets.py:706, in TraitType.set(self, obj, value)
#     702     silent = False
#     703 if silent is not True:
#     704     # we explicitly compare silent to True just in case the equality
#     705     # comparison above returns something other than True/False
# --> 706     obj._notify_trait(self.name, old_value, new_value)
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/traitlets/traitlets.py:1513, in HasTraits._notify_trait(self, name, old_value, new_value)
#    1512 def _notify_trait(self, name: str, old_value: t.Any, new_value: t.Any) -> None:
# -> 1513     self.notify_change(
#    1514         Bunch(
#    1515             name=name,
#    1516             old=old_value,
#    1517             new=new_value,
#    1518             owner=self,
#    1519             type="change",
#    1520         )
#    1521     )
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/ipywidgets/widgets/widget.py:700, in Widget.notify_change(self, change)
#     696 if self.comm is not None and getattr(self.comm, 'kernel', True) is not None:
#     697     # Make sure this isn't information that the front-end just sent us.
#     698     if name in self.keys and self._should_send_property(name, getattr(self, name)):
#     699         # Send new state to front-end
# --> 700         self.send_state(key=name)
#     701 super().notify_change(change)
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/ipywidgets/widgets/widget.py:578, in Widget.send_state(self, key)
#     570 def send_state(self, key=None):
#     571     """Sends the widget state, or a piece of it, to the front-end, if it exists.
#     572
#     573     Parameters
#    (...)
#     576         A single property's name or iterable of property names to sync with the front-end.
#     577     """
# --> 578     state = self.get_state(key=key)
#     579     if len(state) > 0:
#     580         if self._property_lock:  # we need to keep this dict up to date with the front-end values
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/ipywidgets/widgets/widget.py:615, in Widget.get_state(self, key, drop_defaults)
#     613 for k in keys:
#     614     to_json = self.trait_metadata(k, 'to_json', self._trait_to_json)
# --> 615     value = to_json(getattr(self, k), self)
#     616     if not drop_defaults or not self._compare(value, traits[k].default_value):
#     617         state[k] = value
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/ipywidgets/widgets/widget.py:52, in _widget_to_json(x, obj)
#      50     return {k: _widget_to_json(v, obj) for k, v in x.items()}
#      51 elif isinstance(x, (list, tuple)):
# ---> 52     return [_widget_to_json(v, obj) for v in x]
#      53 elif isinstance(x, Widget):
#      54     return "IPY_MODEL_" + x.model_id
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/ipywidgets/widgets/widget.py:54, in _widget_to_json(x, obj)
#      52     return [_widget_to_json(v, obj) for v in x]
#      53 elif isinstance(x, Widget):
# ---> 54     return "IPY_MODEL_" + x.model_id
#      55 else:
#      56     return x
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/ipywidgets/widgets/widget.py:552, in Widget.model_id(self)
#     547 @property
#     548 def model_id(self):
#     549     """Gets the model id of this widget.
#     550
#     551     If a Comm doesn't exist yet, a Comm will be created automagically."""
# --> 552     return self.comm.comm_id
#
# File ~/miniconda3/envs/myenv/lib/python3.12/site-packages/traitlets/traitlets.py:687, in TraitType.__get__(self, obj, cls)
#     685     return self
#     686 else:
# --> 687     return t.cast(G, self.get(obj, cls))
#
# File ~/miniconda3/envs/myenv/lib/python3.12/typing.py:2173, in cast(typ, val)
#    2169                 cls.__non_callable_proto_members__.add(attr)
#    2170     return cls
# -> 2173 def cast(typ, val):
#    2174     """Cast a value to a type.
#    2175
#    2176     This returns the value unchanged.  To the type checker this
#    (...)
#    2179     to be as fast as possible).
#    2180     """
#    2181     return val
#
# KeyboardInterrupt:
